# %%
import pandas as pd
import numpy as np
from skimpy import clean_columns
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# - [Guide for Generating PDFs](https://towardsdatascience.com/how-to-create-pdf-reports-with-python-the-essential-guide-c08dd3ebf2ee)
# - [Dynamic PDF Generation](https://advicement.io/dynamic-documents-api/documentation/getting-started)

# %% [markdown]
# ### Climate Data

# %%
climate = pd.read_csv('Data/2023_scm_climate.csv')
climate["date"] = pd.to_datetime(climate["date"], format='%m/%d/%y')
climate["week"] = climate["date"].dt.strftime("%U").astype(int) 
climate
# Out:
#            recordId  longitude  latitude  elevation       date  rainInches  \
# 0      DEG_DIE_HILL   -76.1495   42.6025       1339 2023-01-01        0.12
# 1      DEG_DIE_HILL   -76.1495   42.6025       1339 2023-01-02        0.00
# 2      DEG_DIE_HILL   -76.1495   42.6025       1339 2023-01-03        0.00
# 3      DEG_DIE_HILL   -76.1495   42.6025       1339 2023-01-04        0.53
# 4      DEG_DIE_HILL   -76.1495   42.6025       1339 2023-01-05        0.35
# ...             ...        ...       ...        ...        ...         ...
# 10131       ZUE_REE   -76.9833   42.7834        669 2023-06-26        0.06
# 10132       ZUE_REE   -76.9833   42.7834        669 2023-06-27        1.24
# 10133       ZUE_REE   -76.9833   42.7834        669 2023-06-28        0.10
# 10134       ZUE_REE   -76.9833   42.7834        669 2023-06-29        0.01
# 10135       ZUE_REE   -76.9833   42.7834        669 2023-06-30        0.00
#
#        minTempF  aveTempF  maxTempF  week
# 0          36.6      43.8      51.1     1
# 1          36.0      38.8      41.5     1
# 2          31.5      39.4      47.2     1
# 3          36.7      44.9      53.1     1
# 4          37.5      46.9      56.2     1
# ...         ...       ...       ...   ...
# 10131      66.3      74.2      82.2    26
# 10132      63.4      72.7      82.1    26
# 10133      60.4      70.2      80.0    26
# 10134      58.7      62.8      66.9    26
# 10135      60.2      68.1      75.9    26
#
# [10136 rows x 10 columns]

# %% [markdown]
# ### Landscape Data

# %%
landscape_500 = pd.read_csv('../2022/Landscape/2022_scm_cdl_500m.csv')
landscape_500["Prop_Corn"] = landscape_500['Corn'] / landscape_500['Total']
landscape_500
# Out:
#          Site_ID  Corn  Open Water  Sweet Corn  Developed/Open Space  \
# 0        STA_LOT    97           0           0                    36
# 1        STA_PAD   297           1           0                    63
# 2        STA_CRA    24           0           0                    74
# 3        POV_DUN     6           0           0                    64
# 4   DEG_FES_OVO4   341           0           0                    46
# ..           ...   ...         ...         ...                   ...
# 75           YOU     3           0           0                    58
# 76           HAT    79           0           0                    43
# 77           MOO   248           0           0                    31
# 78           URI   207          12           0                    11
# 79       MIL_HUM   225           0           0                    26
#
#     Developed/Low Intensity  Developed/Med Intensity  \
# 0                        28                       23
# 1                        37                        5
# 2                        18                        4
# 3                        12                        0
# 4                        46                        3
# ..                      ...                      ...
# 75                       36                        7
# 76                       28                       11
# 77                       16                        4
# 78                       44                       14
# 79                       31                       20
#
#     Developed/High Intensity  Barren  Deciduous Forest  ...   Ag_Prop  Nat  \
# 0                          3       6                14  ...  0.493040   31
# 1                          0       1                16  ...  0.431702   21
# 2                          0       3                65  ...  0.321402  137
# 3                          0       0               220  ...  0.011730  391
# 4                          0       0                81  ...  0.421053   98
# ..                       ...     ...               ...  ...       ...  ...
# 75                         0       0               306  ...  0.005844  495
# 76                        14      10               287  ...  0.079063  456
# 77                         0       0                85  ...  0.352381  131
# 78                         1       0               120  ...  0.434942  126
# 79                        12       0                63  ...  0.477306   68
#
#     Nat_Prop  Semi_Nat  Semi_Nat_Prop  Dev  Dev_Prop  Other  Other_Prop  \
# 0   0.022711        52       0.038095   96  0.070330      0    0.000000
# 1   0.015340       138       0.100804  106  0.077429      1    0.000730
# 2   0.100073       155       0.113221   99  0.072316      0    0.000000
# 3   0.286657       301       0.220674   76  0.055718      0    0.000000
# 4   0.071637        72       0.052632   95  0.069444      0    0.000000
# ..       ...       ...            ...  ...       ...    ...         ...
# 75  0.361578       235       0.171658  101  0.073776      0    0.000000
# 76  0.333821       183       0.133968  106  0.077599      0    0.000000
# 77  0.095971       176       0.128938   51  0.037363      0    0.000000
# 78  0.092105        47       0.034357   70  0.051170     12    0.008772
# 79  0.049780        40       0.029283   89  0.065154      0    0.000000
#
#     Prop_Corn
# 0    0.071062
# 1    0.216947
# 2    0.017531
# 3    0.004399
# 4    0.249269
# ..        ...
# 75   0.002191
# 76   0.057833
# 77   0.181685
# 78   0.151316
# 79   0.164714
#
# [80 rows x 72 columns]

# %%
landscape_1000 = pd.read_csv('../2022/Landscape/2022_scm_cdl_1000m.csv')
landscape_1000["Prop_Corn"] = landscape_1000['Corn'] / landscape_1000['Total']
landscape_1000
# Out:
#          Site_ID  Corn  Open Water  Sweet Corn  Developed/Open Space  \
# 0        STA_LOT   599           1           3                   114
# 1        STA_PAD   907           1           0                   398
# 2        STA_CRA   180           0           0                   163
# 3        POV_DUN    10           4           0                   315
# 4   DEG_FES_OVO4   962           0           0                   151
# ..           ...   ...         ...         ...                   ...
# 75           YOU    10           9           1                   287
# 76           HAT   166           1           8                   117
# 77           MOO   706           6           2                   192
# 78           URI   710          15           0                    58
# 79       MIL_HUM   909           2           0                   105
#
#     Developed/Low Intensity  Developed/Med Intensity  \
# 0                        65                       30
# 1                       318                       31
# 2                        42                       11
# 3                       105                       26
# 4                        89                       12
# ..                      ...                      ...
# 75                      173                       41
# 76                      117                       59
# 77                      102                       22
# 78                       91                       21
# 79                       65                       35
#
#     Developed/High Intensity  Barren  Deciduous Forest  ...   Ag_Prop   Nat  \
# 0                          3       7               179  ...  0.534363   256
# 1                          6       1               353  ...  0.344913   521
# 2                          2       5               650  ...  0.319516  1152
# 3                          5       6               960  ...  0.020838  1678
# 4                          1       0               899  ...  0.404970   989
# ..                       ...     ...               ...  ...       ...   ...
# 75                         2       2               931  ...  0.005822  1771
# 76                        62      28              1204  ...  0.145954  1756
# 77                         1       1               545  ...  0.317013   792
# 78                         1       0               344  ...  0.581302   397
# 79                        14       0               589  ...  0.488466   650
#
#     Nat_Prop  Semi_Nat  Semi_Nat_Prop  Dev  Dev_Prop  Other  Other_Prop  \
# 0   0.057309       280       0.062682  219  0.049026      1    0.000224
# 1   0.116764       617       0.138279  754  0.168983      1    0.000224
# 2   0.258122       498       0.111584  223  0.049966      0    0.000000
# 3   0.375980       913       0.204571  457  0.102397      4    0.000896
# 4   0.221401       273       0.061115  253  0.056638      0    0.000000
# ..       ...       ...            ...  ...       ...    ...         ...
# 75  0.396552      1020       0.228392  505  0.113077      9    0.002015
# 76  0.392490       612       0.136790  383  0.085606      1    0.000224
# 77  0.177062       734       0.164096  318  0.071093      6    0.001341
# 78  0.088794       208       0.046522  171  0.038246     15    0.003355
# 79  0.145577       321       0.071892  219  0.049048      2    0.000448
#
#     Prop_Corn
# 0    0.134094
# 1    0.203272
# 2    0.040332
# 3    0.002241
# 4    0.215357
# ..        ...
# 75   0.002239
# 76   0.037103
# 77   0.157836
# 78   0.158801
# 79   0.203583
#
# [80 rows x 72 columns]

# %%
landscape_2000 = pd.read_csv('../2022/Landscape/2022_scm_cdl_2000m.csv')
landscape_2000["Prop_Corn"] = landscape_2000['Corn'] / landscape_2000['Total']
landscape_2000
# Out:
#          Site_ID  Corn  Open Water  Sweet Corn  Developed/Open Space  \
# 0        STA_LOT  2857           3          10                   810
# 1        STA_PAD  2626           5           1                  1124
# 2        STA_CRA  1550          11           0                   689
# 3        POV_DUN    88          78           2                  1221
# 4   DEG_FES_OVO4  2245           0           2                   756
# ..           ...   ...         ...         ...                   ...
# 75           YOU    75          25           3                   886
# 76           HAT   496           1           8                   680
# 77           MOO  2316          11           6                   490
# 78           URI  2497          19         263                   257
# 79       MIL_HUM  2564           2           0                  1131
#
#     Developed/Low Intensity  Developed/Med Intensity  \
# 0                       506                      134
# 1                       715                       63
# 2                       217                       34
# 3                       408                       94
# 4                       267                       31
# ..                      ...                      ...
# 75                      664                      112
# 76                      640                      220
# 77                      507                      133
# 78                      372                       75
# 79                      794                       96
#
#     Developed/High Intensity  Barren  Deciduous Forest  ...   Ag_Prop   Nat  \
# 0                         30      17              1228  ...  0.542664  1958
# 1                          6       9              2721  ...  0.288983  3923
# 2                          7       7              3241  ...  0.273644  6034
# 3                         21     123              3835  ...  0.032850  7209
# 4                          9       5              4703  ...  0.298525  5608
# ..                       ...     ...               ...  ...       ...   ...
# 75                         5       5              4110  ...  0.009959  7733
# 76                       113      31              4763  ...  0.212669  5805
# 77                        23       3              2524  ...  0.276132  3751
# 78                        21      10              2178  ...  0.530947  2785
# 79                        17       0              3428  ...  0.328943  4237
#
#     Nat_Prop  Semi_Nat  Semi_Nat_Prop   Dev  Dev_Prop  Other  Other_Prop  \
# 0   0.123393      1109       0.069889  1497  0.094341      3    0.000189
# 1   0.247258      3059       0.192802  1917  0.120824      5    0.000315
# 2   0.380190      2069       0.130364   954  0.060110     11    0.000693
# 3   0.454540      3400       0.214376  1867  0.117718     78    0.004918
# 4   0.353416      1838       0.115831  1068  0.067305      0    0.000000
# ..       ...       ...            ...   ...       ...    ...         ...
# 75  0.487425      3870       0.243933  1672  0.105389     25    0.001576
# 76  0.365900      2360       0.148755  1684  0.106146      1    0.000063
# 77  0.236477      3202       0.201866  1156  0.072879     11    0.000693
# 78  0.175533      1365       0.086033   735  0.046325     19    0.001198
# 79  0.266999      2045       0.128868  2038  0.128426      2    0.000126
#
#     Prop_Corn
# 0    0.180048
# 1    0.165511
# 2    0.097662
# 3    0.005549
# 4    0.141480
# ..        ...
# 75   0.004727
# 76   0.031264
# 77   0.146009
# 78   0.157381
# 79   0.161573
#
# [80 rows x 72 columns]

# %% [markdown]
# ### Adult Abundance Count Data

# %%
scm_counts = pd.read_csv("Data/2023_scm_counts.csv")
scm_counts = clean_columns(scm_counts)
scm_counts["date"] = pd.to_datetime(scm_counts["date"], format='%m/%d/%y')
scm_counts["week"] = scm_counts["date"].dt.strftime("%U").astype(int) 
scm_counts
# Out:
#      card_id   data_collector       site       date  n_scm_i_m  n_scm_i_f  \
# 0       2001     Anna DiPaola    DIP_CUR 2023-03-13        0.0        0.0
# 1       2002     Anna DiPaola    DIP_CUR 2023-03-13        0.0        0.0
# 2       2003     Anna DiPaola    POV_DUN 2023-03-13        0.0        0.0
# 3       2004     Anna DiPaola    POV_DUN 2023-03-13        0.0        0.0
# 4       2005     Anna DiPaola    DIP_FLE 2023-03-13        0.0        0.0
# ..       ...              ...        ...        ...        ...        ...
# 421     2422  Roberto Regaldo  WIS_KEN_1 2023-05-05        NaN        NaN
# 422     2423         Ken Wise  WIS_COO_1 2023-05-03        NaN        NaN
# 423     2424         Ken Wise  WIS_COO_1 2023-05-03        NaN        NaN
# 424     2425         Ken Wise  WIS_COO_2 2023-05-03        NaN        NaN
# 425     2426         Ken Wise  WIS_COO_2 2023-05-03        NaN        NaN
#
#      n_scm_o_m  n_scm_o_f  n_d_florilega_i  n_d_florilega_o initials notes  \
# 0          0.0        0.0              0.0              0.0      YVH   NaN
# 1          0.0        0.0              0.0              0.0      YVH   NaN
# 2          0.0        0.0              0.0              0.0      YVH   NaN
# 3          0.0        0.0              0.0              0.0      YVH   NaN
# 4          0.0        0.0              0.0              0.0      YVH   NaN
# ..         ...        ...              ...              ...      ...   ...
# 421        NaN        NaN              NaN              NaN      NaN   NaN
# 422        NaN        NaN              NaN              NaN      NaN   NaN
# 423        NaN        NaN              NaN              NaN      NaN   NaN
# 424        NaN        NaN              NaN              NaN      NaN   NaN
# 425        NaN        NaN              NaN              NaN      NaN   NaN
#
#      week
# 0      11
# 1      11
# 2      11
# 3      11
# 4      11
# ..    ...
# 421    18
# 422    18
# 423    18
# 424    18
# 425    18
#
# [426 rows x 13 columns]

# %% [markdown]
# ### GDD Data

# %%
gdd = pd.read_csv("Data/2023_scm_gdd.csv")
gdd = clean_columns(gdd)
gdd["date"] = pd.to_datetime(gdd["date"], format='%Y-%m-%d')
gdd["week"] = gdd["date"].dt.strftime("%U").astype(int) 
gdd
# Out:
#        record_id       date  temp_max_f  temp_min_f  temp_mean_f  \
# 0        POV_DUN 2023-01-01          51          36         43.5
# 1        POV_DUN 2023-01-02          43          37         40.0
# 2        POV_DUN 2023-01-03          48          29         38.5
# 3        POV_DUN 2023-01-04          52          38         45.0
# 4        POV_DUN 2023-01-05          57          37         47.0
# ...          ...        ...         ...         ...          ...
# 10131  ONE_STA_1 2023-06-26          80          65         72.5
# 10132  ONE_STA_1 2023-06-27          85          65         75.0
# 10133  ONE_STA_1 2023-06-28          80          62         71.0
# 10134  ONE_STA_1 2023-06-29          67          59         63.0
# 10135  ONE_STA_1 2023-06-30          80          56         68.0
#
#        gdd_fahrenheit_simple  gdd_fahrenheit_sine  \
# 0                        4.5             5.083043
# 1                        1.0             1.509001
# 2                        0.0             2.779669
# 3                        6.0             6.115838
# 4                        8.0             8.273364
# ...                      ...                  ...
# 10131                   33.5            33.500000
# 10132                   36.0            36.000000
# 10133                   32.0            32.000000
# 10134                   24.0            24.000000
# 10135                   29.0            29.000000
#
#        gdd_fahrenheit_simple_cumsum  gdd_fahrenheit_sine_cum_sum  temp_max_c  \
# 0                               4.5                     5.083043   10.555556
# 1                               5.5                     6.592044    6.111111
# 2                               5.5                     9.371713    8.888889
# 3                              11.5                    15.487552   11.111111
# 4                              19.5                    23.760915   13.888889
# ...                             ...                          ...         ...
# 10131                        1438.0                  1496.852715   26.666667
# 10132                        1474.0                  1532.852715   29.444444
# 10133                        1506.0                  1564.852715   26.666667
# 10134                        1530.0                  1588.852715   19.444444
# 10135                        1559.0                  1617.852715   26.666667
#
#        temp_min_c  temp_mean_c  gdd_celsius_simple  gdd_celsius_sine  \
# 0        2.222222     6.388889            2.500000          2.823913
# 1        2.777778     4.444444            0.555556          0.838334
# 2       -1.666667     3.611111            0.000000          1.544261
# 3        3.333333     7.222222            3.333333          3.397688
# 4        2.777778     8.333333            4.444444          4.596313
# ...           ...          ...                 ...               ...
# 10131   18.333333    22.500000           18.611111         18.611111
# 10132   18.333333    23.888889           20.000000         20.000000
# 10133   16.666667    21.666667           17.777778         17.777778
# 10134   15.000000    17.222222           13.333333         13.333333
# 10135   13.333333    20.000000           16.111111         16.111111
#
#        gdd_celsius_simple_cum_sum  gdd_celsius_sine_cum_sum  week
# 0                        2.500000                  2.823913     1
# 1                        3.055556                  3.662247     1
# 2                        3.055556                  5.206507     1
# 3                        6.388889                  8.604195     1
# 4                       10.833333                 13.200508     1
# ...                           ...                       ...   ...
# 10131                  798.888889                831.584842    26
# 10132                  818.888889                851.584842    26
# 10133                  836.666667                869.362619    26
# 10134                  850.000000                882.695953    26
# 10135                  866.111111                898.807064    26
#
# [10136 rows x 17 columns]

# %% [markdown]
# ### Wire Mesh Data (Risk)

# %%
wire_mesh = pd.read_csv("Data/2023_wire_mesh.csv")
wire_mesh = clean_columns(wire_mesh)
wire_mesh["number_wireworm"] = (
    wire_mesh["number_wireworm"].replace(">10", 10).astype(float)
)
wire_mesh["total_phorid_maggots"] = (
    wire_mesh["total_phorid_maggots"].replace(">10", 10).astype(float)
)
wire_mesh["total_phorid_pupae"] = (
    wire_mesh["total_phorid_pupae"].replace(">10", 10).astype(float)
)

wire_mesh
# Out:
#           id  container_number project seed_type  number_seeds  scm_seeds  \
# 0        1.0            3011.0       R      Bean           8.0        1.0
# 1        2.0            3011.0       R     Loose           NaN        NaN
# 2        3.0            3011.0       R     Total           8.0        1.0
# 3        4.0            3009.0       R      Corn          10.0        0.0
# 4        5.0            3009.0       R     Loose           NaN        NaN
# ...      ...               ...     ...       ...           ...        ...
# 5446  5447.0               NaN     NaN     Loose           NaN        NaN
# 5447  5448.0               NaN     NaN     Total           0.0        0.0
# 5448  5449.0               NaN     NaN      Bean           NaN        NaN
# 5449  5450.0               NaN     NaN     Loose           NaN        NaN
# 5450     NaN               NaN     NaN     Total           0.0        0.0
#
#       other_seeds  total_scm_maggots  total_scm_pupae  number_wireworm  \
# 0             2.0                1.0              2.0              0.0
# 1             NaN                0.0              0.0              0.0
# 2             2.0                1.0              2.0              0.0
# 3             1.0                0.0              0.0              0.0
# 4             NaN                0.0              0.0              0.0
# ...           ...                ...              ...              ...
# 5446          NaN                NaN              NaN              NaN
# 5447          0.0                0.0              0.0              0.0
# 5448          NaN                NaN              NaN              NaN
# 5449          NaN                NaN              NaN              NaN
# 5450          0.0                0.0              0.0              0.0
#
#       phorid_seeds  total_phorid_maggots  total_phorid_pupae notes
# 0              1.0                   1.0                 1.0   NaN
# 1              NaN                   1.0                 2.0   NaN
# 2              1.0                   2.0                 3.0   NaN
# 3              0.0                   0.0                 0.0   NaN
# 4              NaN                   0.0                 0.0   NaN
# ...            ...                   ...                 ...   ...
# 5446           NaN                   NaN                 NaN   NaN
# 5447           0.0                   0.0                 0.0   NaN
# 5448           NaN                   NaN                 NaN   NaN
# 5449           NaN                   NaN                 NaN   NaN
# 5450           0.0                   0.0                 0.0   NaN
#
# [5451 rows x 14 columns]

# %% [markdown]
# ### Wire Mesh Intake
#
# Contains mapping for container ID and field ID.

# %%
wire_mesh_intake = pd.read_csv("Data/2023_wire_mesh_intake.csv")
wire_mesh_intake = clean_columns(wire_mesh_intake)
wire_mesh_intake
# Out:
#       container_number   container_type project record_id collection_date  \
# 0                 3001         deli cup       R   POV_DUN         4/18/23
# 1                 3002         deli cup       R   POV_DUN         4/18/23
# 2                 3003         deli cup       R   DIP_CUR         4/18/23
# 3                 3004         deli cup       R   DIP_CUR         4/18/23
# 4                 3005         deli cup       R   DIP_PAT         4/18/23
# ...                ...              ...     ...       ...             ...
# 2135              5134  sushi container       R   SMI_CAN         6/12/23
# 2136              5135  sushi container       R   SMI_KEL         6/27/23
# 2137              5136  sushi container       R   SMI_KEL         6/27/23
# 2138              5137  sushi container       R   SMI_KEL         6/27/23
# 2139              5138  sushi container       R   SMI_KEL         6/27/23
#
#      notes
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 2135   NaN
# 2136   NaN
# 2137   NaN
# 2138   NaN
# 2139   NaN
#
# [2140 rows x 6 columns]

# %%
wire_mesh = wire_mesh.merge(
    wire_mesh_intake[["container_number", "container_type", 'collection_date', "record_id"]],
    on="container_number",
    how="left",
)
wire_mesh
# Out:
#           id  container_number project seed_type  number_seeds  scm_seeds  \
# 0        1.0            3011.0       R      Bean           8.0        1.0
# 1        2.0            3011.0       R     Loose           NaN        NaN
# 2        3.0            3011.0       R     Total           8.0        1.0
# 3        4.0            3009.0       R      Corn          10.0        0.0
# 4        5.0            3009.0       R     Loose           NaN        NaN
# ...      ...               ...     ...       ...           ...        ...
# 5455  5447.0               NaN     NaN     Loose           NaN        NaN
# 5456  5448.0               NaN     NaN     Total           0.0        0.0
# 5457  5449.0               NaN     NaN      Bean           NaN        NaN
# 5458  5450.0               NaN     NaN     Loose           NaN        NaN
# 5459     NaN               NaN     NaN     Total           0.0        0.0
#
#       other_seeds  total_scm_maggots  total_scm_pupae  number_wireworm  \
# 0             2.0                1.0              2.0              0.0
# 1             NaN                0.0              0.0              0.0
# 2             2.0                1.0              2.0              0.0
# 3             1.0                0.0              0.0              0.0
# 4             NaN                0.0              0.0              0.0
# ...           ...                ...              ...              ...
# 5455          NaN                NaN              NaN              NaN
# 5456          0.0                0.0              0.0              0.0
# 5457          NaN                NaN              NaN              NaN
# 5458          NaN                NaN              NaN              NaN
# 5459          0.0                0.0              0.0              0.0
#
#       phorid_seeds  total_phorid_maggots  total_phorid_pupae notes  \
# 0              1.0                   1.0                 1.0   NaN
# 1              NaN                   1.0                 2.0   NaN
# 2              1.0                   2.0                 3.0   NaN
# 3              0.0                   0.0                 0.0   NaN
# 4              NaN                   0.0                 0.0   NaN
# ...            ...                   ...                 ...   ...
# 5455           NaN                   NaN                 NaN   NaN
# 5456           0.0                   0.0                 0.0   NaN
# 5457           NaN                   NaN                 NaN   NaN
# 5458           NaN                   NaN                 NaN   NaN
# 5459           0.0                   0.0                 0.0   NaN
#
#      container_type collection_date record_id
# 0          deli cup         4/17/23   GAB_ALL
# 1          deli cup         4/17/23   GAB_ALL
# 2          deli cup         4/17/23   GAB_ALL
# 3          deli cup         4/17/23   GAB_STE
# 4          deli cup         4/17/23   GAB_STE
# ...             ...             ...       ...
# 5455            NaN             NaN       NaN
# 5456            NaN             NaN       NaN
# 5457            NaN             NaN       NaN
# 5458            NaN             NaN       NaN
# 5459            NaN             NaN       NaN
#
# [5460 rows x 17 columns]

# %%
bean_containers = wire_mesh[wire_mesh['seed_type']=='Bean']
bean_containers = bean_containers['container_number']
bean_containers
# Out:
# 0       3011.0
# 6       3068.0
# 12      3010.0
# 18      3003.0
# 27      3042.0
#          ...
# 5445       NaN
# 5448       NaN
# 5451       NaN
# 5454       NaN
# 5457       NaN
# Name: container_number, Length: 1048, dtype: float64

# %%
corn_containers = wire_mesh[wire_mesh['seed_type']=='Corn']
corn_containers = corn_containers['container_number']
corn_containers
# Out:
# 3       3009.0
# 9       3067.0
# 15      3012.0
# 21      3005.0
# 24      3004.0
#          ...
# 5427    5066.0
# 5430    4757.0
# 5433    4844.0
# 5436    5041.0
# 5439    5110.0
# Name: container_number, Length: 772, dtype: float64

# %%
bean_data = wire_mesh[wire_mesh['container_number'].isin(bean_containers)]
bean_data = wire_mesh.loc[wire_mesh['seed_type'] == 'Total']
bean_data.loc[:, 'seed_type'] = 'Bean'
bean_data
# Out:
#           id  container_number project seed_type  number_seeds  scm_seeds  \
# 2        3.0            3011.0       R      Bean           8.0        1.0
# 5        6.0            3009.0       R      Bean          10.0        0.0
# 8        9.0            3068.0       R      Bean           8.0        0.0
# 11      12.0            3067.0       R      Bean          10.0        0.0
# 14      15.0            3010.0       R      Bean          10.0        0.0
# ...      ...               ...     ...       ...           ...        ...
# 5447  5439.0               NaN     NaN      Bean           0.0        0.0
# 5450  5442.0               NaN     NaN      Bean           0.0        0.0
# 5453  5445.0               NaN     NaN      Bean           0.0        0.0
# 5456  5448.0               NaN     NaN      Bean           0.0        0.0
# 5459     NaN               NaN     NaN      Bean           0.0        0.0
#
#       other_seeds  total_scm_maggots  total_scm_pupae  number_wireworm  \
# 2             2.0                1.0              2.0              0.0
# 5             1.0                0.0              0.0              0.0
# 8             0.0                0.0              5.0              1.0
# 11            3.0                0.0              0.0              0.0
# 14            1.0                0.0              0.0              0.0
# ...           ...                ...              ...              ...
# 5447          0.0                0.0              0.0              0.0
# 5450          0.0                0.0              0.0              0.0
# 5453          0.0                0.0              0.0              0.0
# 5456          0.0                0.0              0.0              0.0
# 5459          0.0                0.0              0.0              0.0
#
#       phorid_seeds  total_phorid_maggots  total_phorid_pupae notes  \
# 2              1.0                   2.0                 3.0   NaN
# 5              0.0                   0.0                 0.0   NaN
# 8              2.0                   7.0                 9.0   NaN
# 11             0.0                   0.0                 0.0   NaN
# 14             0.0                   0.0                19.0   NaN
# ...            ...                   ...                 ...   ...
# 5447           0.0                   0.0                 0.0   NaN
# 5450           0.0                   0.0                 0.0   NaN
# 5453           0.0                   0.0                 0.0   NaN
# 5456           0.0                   0.0                 0.0   NaN
# 5459           0.0                   0.0                 0.0   NaN
#
#      container_type collection_date  record_id
# 2          deli cup         4/17/23    GAB_ALL
# 5          deli cup         4/17/23    GAB_STE
# 8          deli cup         4/18/23  SMI_JOH_2
# 11         deli cup         4/18/23  SMI_JOH_2
# 14         deli cup         4/17/23    GAB_STE
# ...             ...             ...        ...
# 5447            NaN             NaN        NaN
# 5450            NaN             NaN        NaN
# 5453            NaN             NaN        NaN
# 5456            NaN             NaN        NaN
# 5459            NaN             NaN        NaN
#
# [1820 rows x 17 columns]

# %%
corn_data = wire_mesh[wire_mesh['container_number'].isin(corn_containers)]
corn_data = wire_mesh.loc[wire_mesh['seed_type'] == 'Total']
corn_data.loc[:, 'seed_type'] = 'Corn'
corn_data
# Out:
#           id  container_number project seed_type  number_seeds  scm_seeds  \
# 2        3.0            3011.0       R      Corn           8.0        1.0
# 5        6.0            3009.0       R      Corn          10.0        0.0
# 8        9.0            3068.0       R      Corn           8.0        0.0
# 11      12.0            3067.0       R      Corn          10.0        0.0
# 14      15.0            3010.0       R      Corn          10.0        0.0
# ...      ...               ...     ...       ...           ...        ...
# 5447  5439.0               NaN     NaN      Corn           0.0        0.0
# 5450  5442.0               NaN     NaN      Corn           0.0        0.0
# 5453  5445.0               NaN     NaN      Corn           0.0        0.0
# 5456  5448.0               NaN     NaN      Corn           0.0        0.0
# 5459     NaN               NaN     NaN      Corn           0.0        0.0
#
#       other_seeds  total_scm_maggots  total_scm_pupae  number_wireworm  \
# 2             2.0                1.0              2.0              0.0
# 5             1.0                0.0              0.0              0.0
# 8             0.0                0.0              5.0              1.0
# 11            3.0                0.0              0.0              0.0
# 14            1.0                0.0              0.0              0.0
# ...           ...                ...              ...              ...
# 5447          0.0                0.0              0.0              0.0
# 5450          0.0                0.0              0.0              0.0
# 5453          0.0                0.0              0.0              0.0
# 5456          0.0                0.0              0.0              0.0
# 5459          0.0                0.0              0.0              0.0
#
#       phorid_seeds  total_phorid_maggots  total_phorid_pupae notes  \
# 2              1.0                   2.0                 3.0   NaN
# 5              0.0                   0.0                 0.0   NaN
# 8              2.0                   7.0                 9.0   NaN
# 11             0.0                   0.0                 0.0   NaN
# 14             0.0                   0.0                19.0   NaN
# ...            ...                   ...                 ...   ...
# 5447           0.0                   0.0                 0.0   NaN
# 5450           0.0                   0.0                 0.0   NaN
# 5453           0.0                   0.0                 0.0   NaN
# 5456           0.0                   0.0                 0.0   NaN
# 5459           0.0                   0.0                 0.0   NaN
#
#      container_type collection_date  record_id
# 2          deli cup         4/17/23    GAB_ALL
# 5          deli cup         4/17/23    GAB_STE
# 8          deli cup         4/18/23  SMI_JOH_2
# 11         deli cup         4/18/23  SMI_JOH_2
# 14         deli cup         4/17/23    GAB_STE
# ...             ...             ...        ...
# 5447            NaN             NaN        NaN
# 5450            NaN             NaN        NaN
# 5453            NaN             NaN        NaN
# 5456            NaN             NaN        NaN
# 5459            NaN             NaN        NaN
#
# [1820 rows x 17 columns]

# %%
wire_mesh = pd.concat([bean_data, corn_data], axis=0) 
wire_mesh = wire_mesh.loc[wire_mesh['project'] == 'R']
wire_mesh["collection_date"] = pd.to_datetime(wire_mesh["collection_date"], format='%m/%d/%y')
wire_mesh["week"] = wire_mesh["collection_date"].dt.strftime("%U").astype(int) 
wire_mesh
# Out:
#           id  container_number project seed_type  number_seeds  scm_seeds  \
# 2        3.0            3011.0       R      Bean           8.0        1.0
# 5        6.0            3009.0       R      Bean          10.0        0.0
# 8        9.0            3068.0       R      Bean           8.0        0.0
# 11      12.0            3067.0       R      Bean          10.0        0.0
# 14      15.0            3010.0       R      Bean          10.0        0.0
# ...      ...               ...     ...       ...           ...        ...
# 5192  5184.0            5033.0       R      Corn          10.0        0.0
# 5237  5229.0            5034.0       R      Corn          10.0        0.0
# 5411  5403.0            4214.0       R      Corn           0.0        0.0
# 5441  5433.0            5110.0       R      Corn          10.0        0.0
# 5444  5436.0            5112.0       R      Corn          10.0        0.0
#
#       other_seeds  total_scm_maggots  total_scm_pupae  number_wireworm  \
# 2             2.0                1.0              2.0              0.0
# 5             1.0                0.0              0.0              0.0
# 8             0.0                0.0              5.0              1.0
# 11            3.0                0.0              0.0              0.0
# 14            1.0                0.0              0.0              0.0
# ...           ...                ...              ...              ...
# 5192          3.0                0.0              0.0              0.0
# 5237          0.0                0.0              0.0              0.0
# 5411          0.0                0.0              0.0              0.0
# 5441          0.0                0.0              0.0              1.0
# 5444          0.0                0.0              0.0              0.0
#
#       phorid_seeds  total_phorid_maggots  total_phorid_pupae notes  \
# 2              1.0                   2.0                 3.0   NaN
# 5              0.0                   0.0                 0.0   NaN
# 8              2.0                   7.0                 9.0   NaN
# 11             0.0                   0.0                 0.0   NaN
# 14             0.0                   0.0                19.0   NaN
# ...            ...                   ...                 ...   ...
# 5192           0.0                   0.0                 1.0   NaN
# 5237           0.0                   0.0                 0.0   NaN
# 5411           0.0                   0.0                 0.0   NaN
# 5441           0.0                   0.0                 0.0   NaN
# 5444           0.0                   0.0                 0.0   NaN
#
#      container_type collection_date  record_id  week
# 2          deli cup      2023-04-17    GAB_ALL    16
# 5          deli cup      2023-04-17    GAB_STE    16
# 8          deli cup      2023-04-18  SMI_JOH_2    16
# 11         deli cup      2023-04-18  SMI_JOH_2    16
# 14         deli cup      2023-04-17    GAB_STE    16
# ...             ...             ...        ...   ...
# 5192       deli cup      2023-06-06    DIP_FLE    23
# 5237       deli cup      2023-06-06    DIP_FLE    23
# 5411       deli cup      2023-05-19    WIS_KEN    20
# 5441       deli cup      2023-06-12    SMI_CAN    24
# 5444       deli cup      2023-06-14    SMI_HOF    24
#
# [570 rows x 18 columns]

# %% [markdown]
# # Adult Abundance

# %% [markdown]
# Farms with first emergence data -
#
# - DIP_CUR
# - DIP_FLE
# - POV_DUN
# - GAB_STE

# %%
first_emergence_farms = ["DIP_CUR", "DIP_FLE", "POV_DUN", "GAB_STE"]
first_emergence_farms
# Out:
# ['DIP_CUR', 'DIP_FLE', 'POV_DUN', 'GAB_STE']

# %%
for farm in first_emergence_farms:
    count_tbl_name = farm + "_counts"
    gdd_tbl_name = farm + "_gdd"

    count_tbl_name = scm_counts[scm_counts["site"] == farm]
    gdd_tbl_name = gdd.loc[gdd["record_id"] == farm]

    pred_avg = gdd_tbl_name.loc[gdd_tbl_name["gdd_fahrenheit_simple_cumsum"] >= 301][
        "date"
    ].values[0]
    pred_sin = gdd_tbl_name.loc[gdd_tbl_name["gdd_fahrenheit_sine_cum_sum"] >= 222][
        "date"
    ].values[0]
    actual = count_tbl_name.loc[
        (count_tbl_name["n_scm_i_m"] >= 1)
        | (count_tbl_name["n_scm_o_m"] >= 1)
        | (count_tbl_name["n_scm_o_f"] >= 1)
        | (count_tbl_name["n_scm_o_f"] >= 1)
    ]["date"].values[0]

    print("The actual first emergence date at " + farm + " is " + actual)

    print(
        "The predicted first emergence date using the simple average model at "
        + farm
        + " is "
        + pred_avg
    )
    print(
        "The predicted date using the simple average model was "
        + str(
            (
                datetime.strptime(pred_avg, "%Y-%m-%d").date()
                - datetime.strptime(actual, "%Y-%m-%d").date()
            ).days
        )
        + " days late"
    )

    print(
        "The predicted first emergence date using the sine wave model at "
        + farm
        + " is "
        + pred_sin
    )
    print(
        "The predicted date using the sine wave model was "
        + str(
            (
                datetime.strptime(pred_sin, "%Y-%m-%d").date()
                - datetime.strptime(actual, "%Y-%m-%d").date()
            ).days
        )
        + " days late"
    )

    print(" ")
# Out:
# The actual first emergence date at DIP_CUR is 2023-04-06
# The predicted first emergence date using the simple average model at DIP_CUR is 2023-04-23
# The predicted date using the simple average model was 17 days late
# The predicted first emergence date using the sine wave model at DIP_CUR is 2023-04-14
# The predicted date using the sine wave model was 8 days late
#
# The actual first emergence date at DIP_FLE is 2023-03-28
# The predicted first emergence date using the simple average model at DIP_FLE is 2023-04-21
# The predicted date using the simple average model was 24 days late
# The predicted first emergence date using the sine wave model at DIP_FLE is 2023-04-12
# The predicted date using the sine wave model was 15 days late
#
# The actual first emergence date at POV_DUN is 2023-03-28
# The predicted first emergence date using the simple average model at POV_DUN is 2023-04-22
# The predicted date using the simple average model was 25 days late
# The predicted first emergence date using the sine wave model at POV_DUN is 2023-04-13
# The predicted date using the sine wave model was 16 days late
#
# The actual first emergence date at GAB_STE is 2023-03-28
# The predicted first emergence date using the simple average model at GAB_STE is 2023-04-18
# The predicted date using the simple average model was 21 days late
# The predicted first emergence date using the sine wave model at GAB_STE is 2023-04-12
# The predicted date using the sine wave model was 15 days late

# %% [markdown]
# ## New GDD Thresholds
#
# Based on average cumulative GDD for four sites with first emergence dates.

# %% [markdown]
# Simple Average Model - GDD Average for Actual Emergence

# %%
np.mean([54, 62.5, 94, 58.5])
# Out:
# 67.25

# %% [markdown]
# Sine Wave Model - GDD Average for Actual Emergence

# %%
np.mean([109.4494181, 118.5207495, 147.4329546, 130.9217006])
# Out:
# 126.5812057
