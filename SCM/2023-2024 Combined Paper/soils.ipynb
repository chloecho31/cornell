# %%
import matplotlib.pyplot as plt
from soilgrids import SoilGrids
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/numpy/__init__.py", line 112, in <module>
#     from numpy.__config__ import show_config
# ImportError: cannot import name 'show_config' from 'numpy.__config__' (/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/numpy/__config__.py)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/vt/gz9c8wh17772k93xq1vtnl0c0000gn/T/ipykernel_17145/1254839580.py", line 1, in <module>
#     import matplotlib.pyplot as plt
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/matplotlib/__init__.py", line 156, in <module>
#     import numpy
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/numpy/__init__.py", line 117, in <module>
#     raise ImportError(msg) from e
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1396, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1287, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1140, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1055, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 955, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/IPython/core/ultratb.py", line 778, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "/Users/chloecho/anaconda3/envs/cornell_dev/lib/python3.11/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# get data from SoilGrids
soil_grids = SoilGrids()
data = soil_grids.get_coverage_data(
    service_id="phh2o",
    coverage_id="phh2o_0-5cm_mean",
    west=-1784000,
    south=1356000,
    east=-1140000,
    north=1863000,
    crs="urn:ogc:def:crs:EPSG::152160",
    local_file=False,
    output="test.tif",
)

# %%
for key, value in soil_grids.metadata.items():
    print('{}: {}'.format(key,value))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for key, value in soil_grids.metadata.items():
#       2     print('{}: {}'.format(key,value))
#
# NameError: name 'soil_grids' is not defined
